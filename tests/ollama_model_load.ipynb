# %%
import os
from dotenv import load_dotenv
from langchain_ollama import OllamaLLM

load_dotenv()

llm = OllamaLLM(base_url=os.environ['OLLAMA_BASE_URL'], model="qllama/bge-reranker-large:latest")
response = llm.invoke("Hello, how are you?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[26], line 8
#       5 load_dotenv()
#       7 llm = OllamaLLM(base_url=os.environ['OLLAMA_BASE_URL'], model="qllama/bge-reranker-large:latest")
# ----> 8 response = llm.invoke("Hello, how are you?")
#       9 print(response)
#
# File ~/miniconda3/envs/llm_learn/lib/python3.10/site-packages/langchain_core/language_models/llms.py:390, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     380 def invoke(
#     381     self,
#     382     input: LanguageModelInput,
#    (...)
#     386     **kwargs: Any,
#     387 ) -> str:
#     388     config = ensure_config(config)
#     389     return (
# --> 390         self.generate_prompt(
#     391             [self._convert_input(input)],
#     392             stop=stop,
#     393             callbacks=config.get("callbacks"),
#     394             tags=config.get("tags"),
# ...
